# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# ans: We have to use the Exception class while creating a Custom Exception because most of the Exception classes in Python extends from the BaseException class. This helps to derive our own exception class from BaseException class or form its subclass.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
import inspect

def treeClass(cls, ind=0):
    
    print('-' * ind, cls.__name__)
    
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
    
print('Hierarchy for Built-in exception is :')

inspect.getclasstree(inspect.getmro(BaseException))

treeClass(BaseException)
# Out:
# Hierarchy for Built-in exception is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# ans: The ArithmeticError Exception is the base class for all errors associated with arithmetic operation.
# # ArithmeticError:
# # a.ZeroDivisionError
# # b.OverflowError
# # c.FloatingPointError

# %% [markdown]
#  ZeroDivisonError: A ZeroDivisionError occurs in Python when a number is attempted to be divided by zero. Since division by zero is not allowed in mathematics, attempting this in Python code raises a ZeroDivisionError .

# %%
try:
    a=10
    b=0
    print(a/b)
except ZeroDivisionError as e:
    print("Error:" , e)
# Out:
# Error: division by zero

# %% [markdown]
# OverflowError: OverflowError occurs when any operations like arithmetic operations or any other variable storing any value above its limit then there occurs an overflow of values that will exceed it's specified or already defined limit.

# %%
j = 5.0

try:
    for i in range(1, 1000):
        j = j**i
        print(j)
except OverflowError as e:
    print("Overflow error happened")
# Out:
# 5.0
# 25.0
# 15625.0
# 5.960464477539062e+16
# 7.52316384526264e+83
# Overflow error happened

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# ans: The LookupError exception in Python forms the base class for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively.

# %% [markdown]
# KeyError is an exception that occurs when an attempt is made to access an item in a dictionary that does not exist.

# %%
try:
    d={"key":"sudh", 1 : [2,3,4,5]}
    print(d["key2"])
except KeyError as e:
    print(e)
# Out:
# 'key2'

# %% [markdown]
# IndexError in Python? IndexError is an exception in python that occurs when we try to access an element from a list or tuple from an index that is not present in the list

# %%
try:
    l=[1,2,4,5,5]
    print(l[6])
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# ImportError: This error generally occurs when a class cannot be imported due to one of the following reasons: The imported class is in a circular dependency. The imported class is unavailable or was not created.

# %%
try:
    import sudh
except ImportError as e:
    print(e)
# Out:
# No module named 'sudh'

# %% [markdown]
# ModuleNotFoundError: The Python interpreter will report the ModuleNotFoundError if you have misspelt the module's name, which prevents it from being found. The module is not installed: You must install the module on your system if it isn't already there before you can import it into your code.

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# ans:
# # always use specific exception
# # always print a proper message
# # always try to log your error
# # always avoid to write a multiple exception handling
